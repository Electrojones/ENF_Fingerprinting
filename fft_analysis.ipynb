# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
#from scipy.fftpack import fft
#
#import scipy
import scipy.fft
import numpy as np
import os

# %matplotlib widget

# %%
rate, data = wav.read('test_440Hz.wav')

# %%
# Number of sample points

N = data.shape[0]

# sample spacing

T = 1.0 / rate

y=data

yf = scipy.fft.fft(y)

xf = scipy.fft.fftfreq(N, T)#[:N//2]

# %%
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(yf.size)
print(np.abs(yf.size))
print(xf.size)
#print(yf.shape)
#print(yf[-2000])
#print(type(yf))

'''
plt.plot(xf[:xf.size], 1/N * np.abs(yf)[:yf.size//2])

plt.grid()
plt.show()
'''
plt.plot(xf[:yf.size//2], np.abs(yf[:yf.size//2]))#[:yf.size//2]

plt.grid()
plt.show()
# Out:
# 1323000
# 1323000
# 1323000

# %%
print(xf[21000])
print(xf[xf.size//2+1])
print(xf.size//2+1)
print(xf[203367])
print(xf[203368])
plt.plot(yf)
plt.show()
# Out:
# 7093.29044117647
# -22049.662224264706
# 65281
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-92-44bbf0d7bc7f> in <module>
#       2 print(xf[xf.size//2+1])
#       3 print(xf.size//2+1)
# ----> 4 print(xf[203367])
#       5 print(xf[203368])
#       6 plt.plot(yf)
#
# IndexError: index 203367 is out of bounds for axis 0 with size 130560

# %%
plt.plot(xf)
plt.show()

# %%
plt.plot(xf[:xf.size//2], 2.0/N * np.abs(yf[:yf.size//2]))

plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-ee1beed8d275> in <module>
# ----> 1 plt.plot(xf[:xf.size//2], 2.0/N * np.abs(yf[:yf.size//2]))
#       2
#       3 plt.grid()
#       4
#       5 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
# ...

# %%
plt.plot(xf, 2.0/N * np.abs(yf[0:yf.size//2]))

plt.grid()

plt.show()

# %%
start=0.00223
stop=0.0025

plt.plot(xf[int(xf.size*start)//2:int(xf.size*stop)//2], 1/N * np.abs(yf[int(xf.size*start)//2:int(xf.size*stop)//2]))

plt.grid()

plt.show()

# %%
yf.shape
# Out:
# (406735, 2)

# %%
plt.plot((xf, np.abs(yf[0:N//2]/N)))

plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-b3b1eaccbb01> in <module>
# ----> 1 plt.plot((xf, np.abs(yf[0:N//2]/N)))
#       2
#       3 plt.grid()
#       4
#       5 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...
